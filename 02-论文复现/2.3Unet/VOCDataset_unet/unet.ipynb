# %%
import matplotlib.pyplot as plt
import cv2

# 读取分割标签图像
seg_img = cv2.imread('VOCdevkit/VOC2012/SegmentationClassPNG/CHNCXR_0001_0.png', cv2.IMREAD_GRAYSCALE)

# 显示图像
plt.figure(figsize=(8,8))
plt.imshow(seg_img, cmap='gray')
plt.title('mask')
plt.axis('off')
plt.show()
